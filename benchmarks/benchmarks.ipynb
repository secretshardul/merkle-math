# %% [markdown]
# # ABDK vs Merkle log benchmarks

# %%
import matplotlib.pyplot as plt
import pandas as pd

columns = ["i", "log", "gas"]
df_abdk = pd.read_csv("abdk.csv", usecols=columns)
df_merkle = pd.read_csv("merkle.csv", usecols=columns)

plt.plot(df_abdk.i, df_abdk.gas, '-.', label="ABDK")
plt.plot(df_merkle.i, df_merkle.gas, label="Merkle")

plt.xlabel("x")
plt.ylabel("gas for log10 (x)")
plt.title('ABDK vs merkle log gas benchmark')

plt.legend()
plt.show()
# Out:
# /home/hp/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
